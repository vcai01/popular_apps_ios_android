# %% [markdown]
# # Popular App Profiles for the App Store and Google Play Markets

# %% [markdown]
# These days nobody would be unfamiliar with Android or iOS mobile applications. There are more than two million apps available on Google Play and the App Store by 2019.
#
# ##We only build apps that are free to download and install, and our main source of revenue consists of in-app ads. This means our revenue for any given app is mostly influenced by the number of users who use our app — the more users that see and engage with the ads, the better.
#
# Here is just a sample of data.
#
# My goal for this project is to analyze data to help developers in a company that builds Android and iOS mobile apps understand what type of apps are likely to attract more users.

# %%
import pandas as pd

ios = pd.read_csv('AppleStore.csv')
print('ios data frame shape: ', ios.shape)
print('Column names:', ios.columns.values)

ios.head()
# Out:
# ios data frame shape:  (7197, 16)
# Column names: ['id' 'track_name' 'size_bytes' 'currency' 'price' 'rating_count_tot'
#  'rating_count_ver' 'user_rating' 'user_rating_ver' 'ver' 'cont_rating'
#  'prime_genre' 'sup_devices.num' 'ipadSc_urls.num' 'lang.num' 'vpp_lic']
#           id               track_name  size_bytes currency  price  \
# 0  284882215                 Facebook   389879808      USD    0.0
# 1  389801252                Instagram   113954816      USD    0.0
# 2  529479190           Clash of Clans   116476928      USD    0.0
# 3  420009108               Temple Run    65921024      USD    0.0
# 4  284035177  Pandora - Music & Radio   130242560      USD    0.0
#
#    rating_count_tot  rating_count_ver  user_rating  user_rating_ver      ver  \
# 0           2974676               212          3.5              3.5     95.0
# 1           2161558              1289          4.5              4.0    10.23
# 2           2130805               579          4.5              4.5  9.24.12
# 3           1724546              3842          4.5              4.0    1.6.2
# 4           1126879              3594          4.0              4.5    8.4.1
#
#   cont_rating        prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 0          4+  Social Networking               37                1        29
# 1         12+      Photo & Video               37                0        29
# 2          9+              Games               38                5        18
# 3          9+              Games               40                5         1
# 4         12+              Music               37                4         1
#
#    vpp_lic
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
android = pd.read_csv('googleplaystore.csv')
print('android data frame shape: ', android.shape)
print('Column names:', android.columns.values)

android.head()
# Out:
# android data frame shape:  (10841, 13)
# Column names: ['App' 'Category' 'Rating' 'Reviews' 'Size' 'Installs' 'Type' 'Price'
#  'Content Rating' 'Genres' 'Last Updated' 'Current Ver' 'Android Ver']
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# Here is <a href="https://www.kaggle.com/lava18/google-play-store-apps">the link</a> to the documentation for detailed column names.

# %% [markdown]
# ## 1. Data Cleaning
#
# ### 1.1 Target Apps
#
# As we are interested in the apps in English that are free to download, we need to select free and English apps exclusively:

# %%
# for example, non-English apps
print(ios.tail(10)['track_name'])

def is_english(string):
    for character in string:
        if ord(character) > 127:
            return False
    return True

ios_target = ios[(ios['track_name'].apply(lambda x: is_english(x))) & (ios['price'] == 0.0)]
print('{} ios apps in total Vs {} free ios apps in English after the filter'.format(len(ios), len(ios_target)))
# Out:
# 7187                     友達 恋人探し であい ちゃっと sns -ギャルとも
# 7188                              【難問謎解き】ねこ神様はクイズ好き？
# 7189            【悲報】鬼ヶ島終了のお知らせ　-ゾンビ桃太郎が3Dすぎて鬼やばいwww-
# 7190                         中学英文法総復習 パターンで覚える 瞬間英文法
# 7191                           Brain15 − 脳トレ 無料パズル −
# 7192    Shark Boom - Challenge Friends with your Pet
# 7193                             【謎解き】ヤミすぎ彼女からのメッセージ
# 7194                                      Go!Go!Cat!
# 7195     Suppin Detective: Expose their true visage!
# 7196             みんなのお弁当 by クックパッド ~お弁当をレシピ付きで記録・共有~
# Name: track_name, dtype: object
# 7197 ios apps in total Vs 2922 free ios apps in English after the filter

# %%
# Note that two features Reviews and Price are string
print(android.dtypes)

android_target = android[(android['App'].apply(lambda x: is_english(x))) & (android['Price'] == '0')]
android_target['Price'] = android_target['Price'].astype(int)
android_target['Reviews'] = android_target['Reviews'].astype(int) 

print('{} Android apps in total Vs {} free andriod apps in English after the filter'.format(len(android), len(android_target)))
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object
# 10841 Android apps in total Vs 9489 free andriod apps in English after the filter
# C:\Data\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Data\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### 1.2 Duplicates and Missing Values
#
# Next step, delete duplicates and check missing values in both datasets.

# %%
print(ios_target[ios_target.duplicated()])
print(ios_target.isna().sum())
# Out:
# Empty DataFrame
# Columns: [id, track_name, size_bytes, currency, price, rating_count_tot, rating_count_ver, user_rating, user_rating_ver, ver, cont_rating, prime_genre, sup_devices.num, ipadSc_urls.num, lang.num, vpp_lic]
# Index: []
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# dtype: int64

# %% [markdown]
# There are no duplicates or missing values in *ios_target* data set.

# %%
print(len(android_target['App'].unique()), 'unique Andriod apps in android_target')

duplicate_rows = android_target[android_target.duplicated('App')]
print('number of duplicate rows: ', duplicate_rows.shape[0])
print(len(duplicate_rows['App'].unique()), 'unique apps in the duplicates')
# Out:
# 8408 unique Andriod apps in android_target
# number of duplicate rows:  1081
# 714 unique apps in the duplicates

# %%
android_target.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1241
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          6
# Android Ver          1
# dtype: int64

# %% [markdown]
# Meanwhile, let's take a close look at the duplicate data in *androidFree*, *Slack* and *Google Ads* as examples.

# %%
android_target[android_target['App'] == 'Slack']
# Out:
#        App  Category  Rating  Reviews                Size    Installs  Type  \
# 240  Slack  BUSINESS     4.4    51507  Varies with device  5,000,000+  Free
# 269  Slack  BUSINESS     4.4    51507  Varies with device  5,000,000+  Free
# 294  Slack  BUSINESS     4.4    51510  Varies with device  5,000,000+  Free
#
#      Price Content Rating    Genres    Last Updated         Current Ver  \
# 240      0       Everyone  Business  August 2, 2018  Varies with device
# 269      0       Everyone  Business  August 2, 2018  Varies with device
# 294      0       Everyone  Business  August 2, 2018  Varies with device
#
#             Android Ver
# 240  Varies with device
# 269  Varies with device
# 294  Varies with device

# %%
android_target[android_target['App'] == 'Google Ads']
# Out:
#              App  Category  Rating  Reviews Size    Installs  Type  Price  \
# 238   Google Ads  BUSINESS     4.3    29313  20M  5,000,000+  Free      0
# 267   Google Ads  BUSINESS     4.3    29313  20M  5,000,000+  Free      0
# 4979  Google Ads  BUSINESS     4.3    29331  20M  5,000,000+  Free      0
#
#      Content Rating    Genres   Last Updated Current Ver   Android Ver
# 238        Everyone  Business  July 30, 2018      1.12.0  4.0.3 and up
# 267        Everyone  Business  July 30, 2018      1.12.0  4.0.3 and up
# 4979       Everyone  Business  July 30, 2018      1.12.0  4.0.3 and up

# %% [markdown]
# From the above examples, the major difference in the duplicate apps is the *Reviews* attribute.
#
# As the higher the number of *Reviews*, the more recent the data should be, I prefer to keep the row with the highest number of *Reviews* and remove the other entries for the same app. But we need to consider three possible combinations of *Rating* and *Reviews* in the duplicate apps:
#
# 1. Different *Reviews*, same *Rating* (NaN or float): we keep the one with more *Reviews*.
# 2. Same *Reviews*, different *Rating* (one is NaN and the other(s) float): we keep the one whose rating is not null.
# 3. Different *Reviews*, different *Rating* (one is NaN and the other(s) float): we keep the one with more *Reviews*. In this case, if *Rating* is null in the selected one, we will impute the missing value with *Rating* in the duplicates.
#
# After checking the following duplicates, I find the second and third combinations do not exist in the dataset which saves me the trouble.

# %%
Nan_list = list(duplicate_rows[duplicate_rows['Rating'].isna()]['App'].unique())

android_target[android_target['App'].str.match('|'.join(Nan_list))].sort_values('App')
# Out:
#                                        App        Category  Rating  Reviews  \
# 2513                        Blood Pressure         MEDICAL     NaN       10
# 6585                        Blood Pressure         MEDICAL     4.2    33033
# 2310                        Blood Pressure         MEDICAL     4.2    33033
# 6621            Blood Pressure - Heartcare         MEDICAL     4.2       70
# 2530         Blood Pressure - Stay Healthy         MEDICAL     4.6        7
# 6609                  Blood Pressure Diary          FAMILY     4.6       47
# 6592                   Blood Pressure Info          FAMILY     3.9   174423
# 6587          Blood Pressure Log - MyDiary         MEDICAL     4.7     8347
# 2323          Blood Pressure Log - MyDiary         MEDICAL     4.7     8348
# 6608      Blood Pressure Log - bpresso.com         MEDICAL     4.2     5661
# 2525                Blood Pressure Monitor         MEDICAL     4.3       17
# 6594                Blood Pressure Monitor         MEDICAL     4.3       17
# 6614                Blood Pressure Tracker         MEDICAL     4.0       11
# 2510              Blood Pressure(BP) Diary         MEDICAL     3.7     3596
# 6590              Blood Pressure(BP) Diary         MEDICAL     3.7     3596
# 6600        Blood Pressure(BP) Report Lite         MEDICAL     4.0       91
# 2529        Breastfeeding Tracker Baby Log         MEDICAL     NaN        6
# 2431        Breastfeeding Tracker Baby Log         MEDICAL     NaN        6
# 6598                   Free Blood Pressure         MEDICAL     NaN        7
# 2502                   Free Blood Pressure         MEDICAL     NaN        7
# 2356                   Free Blood Pressure         MEDICAL     NaN        7
# 2436                           Maricopa AH         MEDICAL     NaN        0
# 5147                           Maricopa AH         MEDICAL     NaN        0
# 23                  Mcqueen Coloring pages  ART_AND_DESIGN     NaN       61
# 2111                Mcqueen Coloring pages          FAMILY     NaN       65
# 2498            Penn State Health OnDemand         MEDICAL     NaN        0
# 2430            Penn State Health OnDemand         MEDICAL     NaN        0
# 2516                            RT 516 VET         MEDICAL     NaN        0
# 2433                            RT 516 VET         MEDICAL     NaN        0
# 666                      Random Video Chat          DATING     NaN        3
# 610                      Random Video Chat          DATING     NaN        3
# 613   Random Video Chat App With Strangers          DATING     NaN        3
# 683   Random Video Chat App With Strangers          DATING     NaN        3
#
#                     Size     Installs  Type  Price Content Rating  \
# 2513                2.4M       1,000+  Free      0       Everyone
# 6585                7.4M   5,000,000+  Free      0       Everyone
# 2310                7.4M   5,000,000+  Free      0       Everyone
# 6621                1.9M      10,000+  Free      0       Everyone
# 2530                2.7M       1,000+  Free      0       Everyone
# 6609                3.3M       5,000+  Free      0       Everyone
# 6592                7.9M  10,000,000+  Free      0       Everyone
# 6587                2.6M     500,000+  Free      0       Everyone
# 2323                2.6M     500,000+  Free      0       Everyone
# 6608  Varies with device     500,000+  Free      0       Everyone
# 2525                6.0M      10,000+  Free      0       Everyone
# 6594                6.0M      10,000+  Free      0       Everyone
# 6614                1.8M       1,000+  Free      0       Everyone
# 2510                8.4M   1,000,000+  Free      0       Everyone
# 6590                8.4M   1,000,000+  Free      0       Everyone
# 6600                335k      10,000+  Free      0       Everyone
# 2529                 23M         100+  Free      0       Everyone
# 2431                 23M         100+  Free      0       Everyone
# 6598                5.7M       5,000+  Free      0       Everyone
# 2502                5.7M       5,000+  Free      0       Everyone
# 2356                5.7M       5,000+  Free      0       Everyone
# 2436                 29M         100+  Free      0       Everyone
# 5147                 29M         100+  Free      0       Everyone
# 23                  7.0M     100,000+  Free      0       Everyone
# 2111                7.0M     100,000+  Free      0       Everyone
# 2498                 40M          50+  Free      0       Everyone
# 2430                 40M          50+  Free      0       Everyone
# 2516                 29M          10+  Free      0       Everyone
# 2433                 29M          10+  Free      0       Everyone
# 666                  16M       1,000+  Free      0     Mature 17+
# 610                  16M       1,000+  Free      0     Mature 17+
# 613                 4.8M       1,000+  Free      0     Mature 17+
# 683                 4.8M       1,000+  Free      0     Mature 17+
#
#                                Genres       Last Updated         Current Ver  \
# 2513                          Medical     March 14, 2015                 1.0
# 6585                          Medical      July 24, 2018              3.27.3
# 2310                          Medical      July 24, 2018              3.27.3
# 6621                          Medical       May 27, 2016          2.46 Saber
# 2530                          Medical     April 16, 2018                43.0
# 6609                       Simulation     August 1, 2018                 1.1
# 6592                    Entertainment     August 2, 2018                2.28
# 6587                          Medical     April 13, 2018               1.4.6
# 2323                          Medical     April 13, 2018               1.4.6
# 6608                          Medical     April 19, 2017  Varies with device
# 2525                          Medical  February 25, 2017               1.0.1
# 6594                          Medical  February 25, 2017               1.0.1
# 6614                          Medical   November 8, 2017               1.1.1
# 2510                          Medical      July 18, 2018               4.0.9
# 6590                          Medical      July 18, 2018               4.0.9
# 6600                          Medical   February 8, 2012                 1.6
# 2529                          Medical      July 20, 2018               1.3.5
# 2431                          Medical      July 20, 2018               1.3.5
# 6598                          Medical   October 13, 2016               3.0.0
# 2502                          Medical   October 13, 2016               3.0.0
# 2356                          Medical   October 13, 2016               3.0.0
# 2436                          Medical      July 16, 2018         300000.1.11
# 5147                          Medical      July 16, 2018         300000.1.11
# 23    Art & Design;Action & Adventure      March 7, 2018               1.0.0
# 2111  Art & Design;Action & Adventure      March 7, 2018               1.0.0
# 2498                          Medical      July 24, 2018       10.4.1.018_06
# 2430                          Medical      July 24, 2018       10.4.1.018_06
# 2516                          Medical      July 13, 2018         300000.1.11
# 2433                          Medical      July 13, 2018         300000.1.11
# 666                            Dating      July 15, 2018                4.20
# 610                            Dating      July 15, 2018                4.20
# 613                            Dating      July 17, 2018                  1.
# 683                            Dating      July 17, 2018                  1.
#
#              Android Ver
# 2513          2.3 and up
# 6585          4.1 and up
# 2310          4.1 and up
# 6621          4.4 and up
# 2530        4.0.3 and up
# 6609        4.0.3 and up
# 6592          4.0 and up
# 6587          4.0 and up
# 2323          4.0 and up
# 6608  Varies with device
# 2525          4.4 and up
# 6594          4.4 and up
# 6614          4.0 and up
# 2510        4.0.3 and up
# 6590        4.0.3 and up
# 6600          2.1 and up
# 2529          5.0 and up
# 2431          5.0 and up
# 6598        4.0.3 and up
# 2502        4.0.3 and up
# 2356        4.0.3 and up
# 2436        4.0.3 and up
# 5147        4.0.3 and up
# 23            4.1 and up
# 2111          4.1 and up
# 2498        4.0.3 and up
# 2430        4.0.3 and up
# 2516        4.0.3 and up
# 2433        4.0.3 and up
# 666         4.0.3 and up
# 610         4.0.3 and up
# 613           4.0 and up
# 683           4.0 and up

# %%
android_final = android_target.sort_values('Reviews', ascending = False).drop_duplicates('App')
print(len(android_final))

# double check
print(len(android_target) - duplicate_rows.shape[0])

android_final[android_target['App'] == 'Slack']
# Out:
# 8408
# 8408
# C:\Data\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#        App  Category  Rating  Reviews                Size    Installs  Type  \
# 294  Slack  BUSINESS     4.4    51510  Varies with device  5,000,000+  Free
#
#      Price Content Rating    Genres    Last Updated         Current Ver  \
# 294      0       Everyone  Business  August 2, 2018  Varies with device
#
#             Android Ver
# 294  Varies with device

# %% [markdown]
# Finally we have 1231 missing values in *Rating* in *android_final* data set after the duplicats are deleted accordingly, which account for 14.64%, much more than 5% of the data. Therefore, we are not able to impute the missing values with the mean of data.

# %%
print(android_final.isna().sum())

rating_na = android_final['Rating'].isna().sum()
print('{0:.2%}'.format(rating_na/len(android_final)))
# Out:
# App                  0
# Category             0
# Rating            1231
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          6
# Android Ver          1
# dtype: int64
# 14.64%

# %% [markdown]
# As a result,there are 2922 ios apps and 7177 Android apps that meet our requirements after the data cleaning.

# %%
ios_target[['user_rating', 'rating_count_tot', 'price']].describe()
# Out:
#        user_rating  rating_count_tot   price
# count  2922.000000      2.922000e+03  2922.0
# mean      3.882444      2.423410e+04     0.0
# std       1.070019      1.120867e+05     0.0
# min       0.000000      0.000000e+00     0.0
# 25%       3.500000      1.350000e+02     0.0
# 50%       4.000000      1.107500e+03     0.0
# 75%       4.500000      9.028250e+03     0.0
# max       5.000000      2.974676e+06     0.0

# %%
android_final = android_final[android_final['Rating'].notna()]
android_final.describe()
# Out:
#             Rating       Reviews   Price
# count  7177.000000  7.177000e+03  7177.0
# mean      4.163258  2.685489e+05     0.0
# std       0.538403  2.002242e+06     0.0
# min       1.000000  1.000000e+00     0.0
# 25%       4.000000  1.370000e+02     0.0
# 50%       4.300000  3.656000e+03     0.0
# 75%       4.500000  4.965700e+04     0.0
# max       5.000000  7.815831e+07     0.0

# %% [markdown]
# ## 2. Discovery
#
# ### 2.1 Genres with the Most Apps

# %%
ios_genre = ios_target.groupby('prime_genre').size().to_frame()
ios_genre.reset_index(inplace = True)
ios_genre['number'] = ios_genre[0]
del ios_genre[0]
ios_genre.sort_values('number', ascending = False, inplace = True)
len(ios_genre)
# Out:
# 23

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,8))
sns.barplot(x = 'number', y = 'prime_genre', data = ios_genre)

plt.title('Number of iOS Apps in Each Genre')
plt.ylabel('Genres')
plt.xlabel('Number of Apps')

for x,y in enumerate(ios_genre['number']):
    plt.text(y+1, x, f'{y}', va='center')

# %% [markdown]
# In *android* dataset, an app can belong to multiple *genres* (apart from its main category). Therefore, *Category* of Android apps is the counterpart feature of *prime_genre* of iOS apps.

# %%
android_final[android_final['Genres'].str.contains(';')][:10]
# Out:
#                                            App Category  Rating   Reviews  \
# 2090  Minion Rush: Despicable Me Official Game   FAMILY     4.5  10216997
# 8439            Duolingo: Learn Languages Free   FAMILY     4.7   6297590
# 2206                                    ROBLOX   FAMILY     4.5   4450890
# 9680                          Frozen Free Fall   FAMILY     4.3   1574546
# 9144                       Madden NFL Football   FAMILY     4.5   1455952
# 4229                    Where's My Water? Free   FAMILY     4.4   1372013
# 2119                                Turbo FAST   FAMILY     4.3   1329192
# 2127                            Toca Kitchen 2   FAMILY     4.5   1014846
# 7589                         Card Wars Kingdom   FAMILY     4.3    920571
# 2229                Inside Out Thought Bubbles   FAMILY     4.4    623398
#
#                     Size      Installs  Type  Price Content Rating  \
# 2090  Varies with device  100,000,000+  Free      0   Everyone 10+
# 8439  Varies with device  100,000,000+  Free      0       Everyone
# 2206                 67M  100,000,000+  Free      0   Everyone 10+
# 9680                 37M   50,000,000+  Free      0       Everyone
# 9144  Varies with device   10,000,000+  Free      0       Everyone
# 4229                 57M  100,000,000+  Free      0       Everyone
# 2119                 97M   50,000,000+  Free      0       Everyone
# 2127                 56M   50,000,000+  Free      0       Everyone
# 7589                 28M   10,000,000+  Free      0   Everyone 10+
# 2229                 58M   10,000,000+  Free      0       Everyone
#
#                             Genres       Last Updated         Current Ver  \
# 2090     Casual;Action & Adventure      July 12, 2018  Varies with device
# 8439           Education;Education     August 6, 2018  Varies with device
# 2206  Adventure;Action & Adventure      July 31, 2018        2.347.225742
# 9680     Puzzle;Action & Adventure      July 27, 2018               6.7.0
# 9144     Sports;Action & Adventure       May 15, 2018               4.3.6
# 4229            Puzzle;Brain Games  November 21, 2017              1.10.0
# 2119     Racing;Action & Adventure    October 4, 2017              2.1.20
# 2127      Educational;Pretend Play      June 29, 2017          1.2.3-play
# 7589       Card;Action & Adventure   January 17, 2017              1.0.10
# 2229            Puzzle;Brain Games    August 31, 2017              1.22.0
#
#              Android Ver
# 2090  Varies with device
# 8439  Varies with device
# 2206          4.1 and up
# 9680          4.2 and up
# 9144          4.0 and up
# 4229          4.1 and up
# 2119        2.3.3 and up
# 2127          4.1 and up
# 7589        4.0.3 and up
# 2229        4.0.3 and up

# %%
android_genre = android_final.groupby('Category').size().to_frame()
android_genre.reset_index(inplace = True)
android_genre['number'] = android_genre[0]
del android_genre[0]
android_genre.sort_values('number', ascending = False, inplace = True)
#len(android_genre)

android_genre
# Out:
#                Category  number
# 11               FAMILY    1401
# 14                 GAME     770
# 29                TOOLS     634
# 12              FINANCE     275
# 25         PRODUCTIVITY     271
# 18            LIFESTYLE     263
# 4              BUSINESS     243
# 24          PHOTOGRAPHY     240
# 15   HEALTH_AND_FITNESS     226
# 28               SPORTS     225
# 6         COMMUNICATION     222
# 20              MEDICAL     221
# 23      PERSONALIZATION     221
# 27               SOCIAL     192
# 21   NEWS_AND_MAGAZINES     188
# 26             SHOPPING     168
# 30     TRAVEL_AND_LOCAL     166
# 3   BOOKS_AND_REFERENCE     155
# 31        VIDEO_PLAYERS     134
# 7                DATING     120
# 19  MAPS_AND_NAVIGATION     104
# 8             EDUCATION      97
# 13       FOOD_AND_DRINK      85
# 9         ENTERTAINMENT      78
# 1     AUTO_AND_VEHICLES      69
# 32              WEATHER      62
# 17   LIBRARIES_AND_DEMO      59
# 16       HOUSE_AND_HOME      57
# 0        ART_AND_DESIGN      54
# 5                COMICS      47
# 22            PARENTING      45
# 10               EVENTS      43
# 2                BEAUTY      42

# %%
plt.figure(figsize=(15,8))
sns.barplot(x = 'number', y = 'Category', data = android_genre)

plt.title('Number of Android Apps in Each Category')
plt.ylabel('Category')
plt.xlabel('Number of Apps')

for x,y in enumerate(android_genre['number']):
    plt.text(y+1, x, f'{y}', va='center')

# %% [markdown]
# ### 2.2 Genres with the Highest Average Reviews

# %% [markdown]
# *Weather* and *Shopping* are two common genres in the Top 10 with highest average reviews in both the App Store and Google Play.
#
# Here are the detailed lists and bar charts.

# %%
ios_grv = ios_target.groupby('prime_genre')['rating_count_tot'].mean().to_frame()
ios_grv.reset_index(inplace = True)
ios_grv.sort_values('rating_count_tot', ascending = False, inplace = True)
ios_grv['rating_count_tot'] = ios_grv['rating_count_tot'].astype(int)
ios_grv.reset_index(drop = True, inplace = True)
ios_grv
# Out:
#           prime_genre  rating_count_tot
# 0          Navigation            125037
# 1           Reference             89562
# 2   Social Networking             78567
# 3               Music             55396
# 4             Weather             48275
# 5              Travel             34115
# 6        Food & Drink             33333
# 7       Photo & Video             29249
# 8            Shopping             28877
# 9             Finance             26038
# 10             Sports             25791
# 11               News             23382
# 12       Productivity             22842
# 13              Games             21560
# 14   Health & Fitness             19418
# 15          Lifestyle             17260
# 16               Book             16671
# 17      Entertainment             15006
# 18          Utilities             11571
# 19           Business              6839
# 20          Education              6103
# 21           Catalogs              5195
# 22            Medical               612

# %%
plt.figure(figsize=(15,8))
sns.set_palette('Pastel1')
sns.barplot(x = 'rating_count_tot', y = 'prime_genre', data = ios_grv[:10])

plt.title('Top 10 Genres with the Highest Average Reviews in iOS Apps')
plt.ylabel('Genre')
plt.xlabel('Reviews')
plt.xlim(20000, 140000)

for x,y in enumerate(ios_grv['rating_count_tot'][:10]):
    plt.text(y+0.01, x, f'{y}', va='center')

# %%
android_grv = android_final.groupby('Category')['Reviews'].mean().to_frame()
android_grv.reset_index(inplace = True)
android_grv.sort_values('Reviews', ascending = False, inplace = True)
android_grv['Reviews'] = android_grv['Reviews'].astype(int)
android_grv.reset_index(drop = True, inplace = True)
android_grv
# Out:
#                Category  Reviews
# 0                SOCIAL  1185853
# 1         COMMUNICATION   985983
# 2                  GAME   707479
# 3         VIDEO_PLAYERS   459698
# 4           PHOTOGRAPHY   431564
# 5                 TOOLS   355381
# 6         ENTERTAINMENT   325207
# 7              SHOPPING   263763
# 8       PERSONALIZATION   208116
# 9               WEATHER   194961
# 10         PRODUCTIVITY   193473
# 11  MAPS_AND_NAVIGATION   168728
# 12     TRAVEL_AND_LOCAL   153188
# 13               SPORTS   139578
# 14               FAMILY   126667
# 15   NEWS_AND_MAGAZINES   120997
# 16   HEALTH_AND_FITNESS    92045
# 17  BOOKS_AND_REFERENCE    88749
# 18       FOOD_AND_DRINK    73250
# 19            EDUCATION    57926
# 20               COMICS    48795
# 21              FINANCE    41267
# 22             BUSINESS    39332
# 23            LIFESTYLE    38590
# 24       HOUSE_AND_HOME    33603
# 25               DATING    27380
# 26       ART_AND_DESIGN    24450
# 27            PARENTING    20687
# 28    AUTO_AND_VEHICLES    16180
# 29   LIBRARIES_AND_DEMO    14084
# 30               BEAUTY     9407
# 31              MEDICAL     4930
# 32               EVENTS     3181

# %%
plt.figure(figsize=(15,8))
sns.set_palette('Pastel1')
sns.barplot(x = 'Reviews', y = 'Category', data = android_grv[:10])

plt.title('Top 10 Categories with the Highest Average Reviews in Android Apps')
plt.ylabel('Category')
plt.xlabel('Reviews')
plt.xlim(180000, 1200000)

for x,y in enumerate(android_grv['Reviews'][:10]):
    plt.text(y+0.01, x, f'{y}', va='center')

# %% [markdown]
# ### 2.3 Genres with the Highest Average Ratings

# %% [markdown]
# *Game*, *Health & Fitness*, and *Reference* are three common genres in the Top 10 with highest average ratings in both the App Store and Google Play.
#
# Here are the detailed lists and bar charts.

# %%
ios_gr = ios_target.groupby('prime_genre')['user_rating'].mean().to_frame()
ios_gr.reset_index(inplace = True)
ios_gr.sort_values('user_rating', ascending = False, inplace = True)
ios_gr['user_rating'] = ios_gr['user_rating'].round(2)
ios_gr.reset_index(drop = True, inplace = True)
ios_gr
# Out:
#           prime_genre  user_rating
# 0            Catalogs         4.17
# 1        Productivity         4.05
# 2               Games         4.05
# 3            Shopping         3.96
# 4               Music         3.94
# 5    Health & Fitness         3.88
# 6          Navigation         3.88
# 7            Business         3.87
# 8       Photo & Video         3.87
# 9           Reference         3.83
# 10  Social Networking         3.64
# 11          Education         3.64
# 12       Food & Drink         3.63
# 13      Entertainment         3.52
# 14          Utilities         3.51
# 15          Lifestyle         3.47
# 16            Weather         3.46
# 17            Finance         3.44
# 18             Travel         3.41
# 19               Book         3.31
# 20               News         3.18
# 21             Sports         3.08
# 22            Medical         3.00

# %%
plt.figure(figsize=(15,8))
sns.set_palette('Pastel1')
sns.barplot(x = 'user_rating', y = 'prime_genre', data = ios_gr[:10])

plt.title('Top 10 Genres with the Highest Average Ratings in iOS Apps')
plt.ylabel('Genre')
plt.xlabel('Rating')
plt.xlim(3, 5)

for x,y in enumerate(ios_gr['user_rating'][:10]):
    plt.text(y+0.01, x, f'{y}', va='center')

# %%
android_gr = android_final.groupby('Category')['Rating'].mean().to_frame()
android_gr.reset_index(inplace = True)
android_gr.sort_values('Rating', ascending = False, inplace = True)
android_gr['Rating'] = android_gr['Rating'].round(2)
android_gr.reset_index(drop = True, inplace = True)
android_gr
# Out:
#                Category  Rating
# 0                EVENTS    4.43
# 1             PARENTING    4.37
# 2   BOOKS_AND_REFERENCE    4.34
# 3             EDUCATION    4.34
# 4        ART_AND_DESIGN    4.33
# 5       PERSONALIZATION    4.30
# 6                BEAUTY    4.28
# 7                SOCIAL    4.25
# 8    HEALTH_AND_FITNESS    4.23
# 9                  GAME    4.23
# 10             SHOPPING    4.22
# 11              WEATHER    4.22
# 12               SPORTS    4.20
# 13         PRODUCTIVITY    4.19
# 14       FOOD_AND_DRINK    4.18
# 15       HOUSE_AND_HOME    4.17
# 16    AUTO_AND_VEHICLES    4.17
# 17               FAMILY    4.17
# 18               COMICS    4.16
# 19          PHOTOGRAPHY    4.16
# 20              MEDICAL    4.15
# 21   LIBRARIES_AND_DEMO    4.14
# 22              FINANCE    4.13
# 23        COMMUNICATION    4.12
# 24   NEWS_AND_MAGAZINES    4.11
# 25             BUSINESS    4.10
# 26        ENTERTAINMENT    4.09
# 27            LIFESTYLE    4.08
# 28     TRAVEL_AND_LOCAL    4.05
# 29  MAPS_AND_NAVIGATION    4.03
# 30                TOOLS    4.02
# 31        VIDEO_PLAYERS    4.02
# 32               DATING    3.99

# %%
plt.figure(figsize=(15,8))
sns.barplot(x = 'Rating', y = 'Category', data = android_gr[:10])

plt.title('Top 10 Categories with the Highest Average Ratings in Android Apps')
plt.ylabel('Category')
plt.xlabel('Rating')
plt.xlim(3, 5)

for x,y in enumerate(android_gr['Rating'][:10]):
    plt.text(y+0.01, x, f'{y}', va='center')
